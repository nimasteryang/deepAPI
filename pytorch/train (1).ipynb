# %%
cd drive/MyDrive/Colab\ Notebooks/pytorch
# Out:
# /content/drive/MyDrive/Colab Notebooks/pytorch

# %%
ls
# Out:
#  bleu_transformer.py   helper.py    __pycache__/      'train (1).ipynb'
#  board.ipynb           metrics.py   README.md          train.ipynb
#  configs.py            models/      requirements.txt   train.py
#  data/                 modules.py   sample.py          train_transformer.py
#  data_loader.py        output/      test.ipynb

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Mon Dec 21 18:21:11 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    22W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python train.py --valid_every=10000 --eval_every=20000 --reload_from=9

# %%
# !python train.py --valid_every=10 --eval_every=100
# Out:
# Namespace(data_path='./data/', eval_every=100, expname='basic', gpu_id=0, log_every=10, model='RNNEncDec', reload_from=-1, sample=False, seed=1111, valid_every=10, visual=False)
# cuda:0
# num of gpus:1
# loading data...
# tcmalloc: large alloc 1262305280 bytes == 0x2ec3c000 @  0x7f37db6971e7 0x7f37d91d741e 0x7f37d9227bdb 0x7f37d9227cf7 0x7f37d92c0967 0x50a4a5 0x50beb4 0x507be4 0x508f37 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7f37db294bf7 0x5b259a
# 7475850 entries
# loading data...
# 10000 entries
# Loaded data!
# model defined!
# Training...
# ...

# %% [markdown]
# ## train the transformer

# %%
# !python train_transformer.py  --eval_every=10000
# Out:
# Streaming output truncated to the last 5000 lines.
#
#   2% 155/10000 [02:11<2:11:51,  1.24it/s]beam searching
#
#
#
#
#
#
#   2% 156/10000 [02:12<2:09:07,  1.27it/s]beam searching
#
#
#
#
#
#
#   2% 157/10000 [02:13<2:02:47,  1.34it/s]beam searching
#
#
#
#
#
#
#   2% 158/10000 [02:14<2:18:39,  1.18it/s]beam searching
#
#
#
#
#
#
#   2% 159/10000 [02:15<3:06:09,  1.13s/it]beam searching
#
#
#
#
#
#
#   2% 160/10000 [02:16<2:46:51,  1.02s/it]beam searching
#
#
#
#
#
#
#   2% 161/10000 [02:17<2:23:14,  1.14it/s]beam searching
#
#
#
#
#
#
#   2% 162/10000 [02:17<2:17:00,  1.20it/s]beam searching
#
#
#
#
#
#
#   2% 163/10000 [02:18<2:11:48,  1.24it/s]beam searching
#
#
#
#
#
#
#   2% 164/10000 [02:19<2:30:18,  1.09it/s]beam searching
#
#
#
#
#
#
#   2% 165/10000 [02:20<2:06:15,  1.30it/s]beam searching
#
#
#
#
#
#
#   2% 166/10000 [02:21<2:05:17,  1.31it/s]beam searching
#
#
#
#
#
#
#   2% 167/10000 [02:21<1:54:41,  1.43it/s]beam searching
#
#
#
#
#
#
# ...
